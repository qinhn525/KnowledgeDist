# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
test_acc = np.loadtxt("./test_acc.txt")
test_f1 = np.loadtxt("./test_f1.txt")
train_acc = np.loadtxt("./trained_acc.txt")
train_f1 = np.loadtxt("./trained_f1.txt")
batch0_acc = np.loadtxt("./trained_acc_on_0_batch.txt")

# %%
diff = train_acc - test_acc[:-1]

# %%
plt.figure(dpi=600, figsize=(7, 5))
# plt.plot(list(range(len(test_acc))), test_acc, label="test_acc", marker=".")
plt.plot(list(range(1, len(train_acc)+1)), train_acc, label="trained_acc", marker="*")
plt.plot(list(range(1, len(batch0_acc)+1)), batch0_acc, label="batch0_acc", marker=".")
# plt.plot(list(range(1, len(train_acc)+1)), diff, label="trained_acc - test_acc", marker=".")
plt.legend(loc="best")
plt.grid()
plt.savefig("output.png", dpi=600)
plt.show()
